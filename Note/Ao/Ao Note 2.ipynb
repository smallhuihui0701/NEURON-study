# %% [markdown]
# # Note 2

# %% [markdown]
# ## Strength-duration curve
#
# The strength-duration curve is a graphical representation that shows the relationship between the strength (intensity) of an electrical stimulus and its duration required to produce a threshold response in neural tissue.
# - Strength: The amplitude of the electrical stimulus.
# - Duration: The time period during which the electrical stimulus is applied.
# - Rheobase: The minimum current needed to generate an action potential when the stimulus duration is infinitely long.
# - Chronaxie: The duration required for a stimulus of twice the rheobase current to produce a response.

# %% [markdown]
# ![Strength-duration_curve.png](attachment:Strength-duration_curve.png)

# %% [markdown]
# ## Compound Muscle Action Potential
# A Compound Action Potential (CAP) is the sum of action potentials from multiple nerve fibers within a nerve bundle.
#
# Unlike a single-neuron action potential, which follows an all-or-none rule, a CAP is a graded response, meaning its amplitude varies depending on how many fibers are activated.

# %% [markdown]
# ## Recruitment curve
# A recruitment curve describes the relationship between the stimulus intensity and the number of activated neurons or fibers in a neural population.
#
# The all-or-none law is a principle that states that the strength of a response of a nerve cell or muscle fiber is not dependent upon the strength of the stimulus. If a stimulus is above a certain threshold, a nerve or muscle fiber will fire.
#
# According to the all-or-none law, there will either be a full response or no response at all for an individual neuron or muscle fiber.

# %% [markdown]
# ![Recruitment_curve.png](attachment:Recruitment_curve.png)

# %% [markdown]
# ## Patch Clamp
# A glass micropipette (patch pipette) with a tip diameter of ~1-2 µm is tightly sealed onto a small patch of the cell membrane.
#
# The electrical activity of ion channels or the whole cell can then be recorded using an amplifier.

# %% [markdown]
# ## Equilibrium
# Equilibrium refers to a state in which opposing forces or processes are balanced, meaning there is no net change over time. It is a fundamental concept in physics, chemistry, biology, and economics.

# %% [markdown]
# ##
