# %%
pip install plotnine
# Out:
# Requirement already satisfied: plotnine in c:\users\xyh19\anaconda3\lib\site-packages (0.13.6)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\xyh19\anaconda3\lib\site-packages (from plotnine) (1.9.1)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\xyh19\anaconda3\lib\site-packages (from plotnine) (1.24.4)
# Requirement already satisfied: mizani~=0.11.0 in c:\users\xyh19\anaconda3\lib\site-packages (from plotnine) (0.11.4)
# Requirement already satisfied: statsmodels>=0.14.0 in c:\users\xyh19\anaconda3\lib\site-packages (from plotnine) (0.14.4)
# Requirement already satisfied: matplotlib>=3.7.0 in c:\users\xyh19\anaconda3\lib\site-packages (from plotnine) (3.9.4)
# Requirement already satisfied: pandas<3.0.0,>=2.1.0 in c:\users\xyh19\anaconda3\lib\site-packages (from plotnine) (2.2.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\xyh19\anaconda3\lib\site-packages (from matplotlib>=3.7.0->plotnine) (6.5.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\xyh19\anaconda3\lib\site-packages (from matplotlib>=3.7.0->plotnine) (4.25.0)
# Requirement already satisfied: pillow>=8 in c:\users\xyh19\anaconda3\lib\site-packages (from matplotlib>=3.7.0->plotnine) (9.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\xyh19\anaconda3\lib\site-packages (from matplotlib>=3.7.0->plotnine) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\xyh19\anaconda3\lib\site-packages (from matplotlib>=3.7.0->plotnine) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\xyh19\anaconda3\lib\site-packages (from matplotlib>=3.7.0->plotnine) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\xyh19\anaconda3\lib\site-packages (from matplotlib>=3.7.0->plotnine) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\xyh19\anaconda3\lib\site-packages (from matplotlib>=3.7.0->plotnine) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\xyh19\anaconda3\lib\site-packages (from matplotlib>=3.7.0->plotnine) (21.3)
# Requirement already satisfied: tzdata in c:\users\xyh19\anaconda3\lib\site-packages (from mizani~=0.11.0->plotnine) (2025.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\xyh19\anaconda3\lib\site-packages (from pandas<3.0.0,>=2.1.0->plotnine) (2022.1)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\xyh19\anaconda3\lib\site-packages (from statsmodels>=0.14.0->plotnine) (1.0.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\xyh19\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.7.0->plotnine) (3.8.0)
# Requirement already satisfied: six>=1.5 in c:\users\xyh19\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->plotnine) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install neuron
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement neuron (from versions: none)
# ERROR: No matching distribution found for neuron

# %%
from neuron.units import mV, ms, µm
import matplotlib.pyplot as plt
from neuron import h
import pandas as pd
from plotnine import ggplot, aes, geom_line, theme_minimal, ggtitle, xlab, ylab, theme, element_rect
h.load_file("stdrun.hoc")

#
# Define the model cell and its dynamics
#

# Create a soma section
soma = h.Section('soma')
soma.L = 10 * µm
soma.diam = 10 * µm
soma.nseg = 1  # single compartment (soma)

# Insert Hodgkin-Huxley mechanisms
soma.insert(h.hh)

#
# setup the experiment: current clamp
#

# Create the current clamp
stim = h.IClamp(soma(0.5))  # Inject current at the center of the soma
stim.delay = 5 * ms
stim.dur = 1 * ms
stim.amp = 0.1  # nA

#
# setup the instrumentation: record time and voltage
#

# Set up the recording of time and voltage
tvec = h.Vector().record(h._ref_t)
vvec = h.Vector().record(soma(0.5)._ref_v)
inavec = h.Vector().record(soma(0.5)._ref_ina)

#
# do the experiment
#

# Run the simulation
h.finitialize(-65)
h.continuerun(10)

#
# analyze the results (in our case, this is just to make a picture)
#

# Create a DataFrame for plotting
data = pd.DataFrame({'Time (ms)': tvec, 'Voltage (mV)': vvec, "ina": inavec})

# Plot the results using plotnine
plot = (ggplot(data, aes(x='Time (ms)', y='Voltage (mV)')) +
        geom_line(color="red") +
        theme(plot_background=element_rect(fill="white")) +
        ggtitle('Hodgkin-Huxley Simulation of Soma') +
        xlab('Time (ms)') +
        ylab('Voltage (mV)'))

plot2 = (ggplot(data, aes(x='Time (ms)', y='ina')) +
        geom_line() +
        theme(plot_background=element_rect(fill="white")) +
        ggtitle('Hodgkin-Huxley Simulation of Soma'))

# Show the plot
plot.show()
plot2.show()
