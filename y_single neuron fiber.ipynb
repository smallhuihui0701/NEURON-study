# %% [markdown]
# # Phase I: single nueron fiber

# %%
from neuron import h
from neuron.units import um, mV, ms
h.load_file("stdrun.hoc")
import plotly

# %%
axon = h.Section(name="axon")

# %%
axon.L = 2000 * um
axon.diam = 4 * um

# %%
axon.nseg = 43

# %%
h.hh.insert(axon)

# %%
icalmp = h.IClamp(axon(0))
icalmp.delay = 1
icalmp.dur = 1
icalmp.amp = 10

# %%
rvp = h.RangeVarPlot("v", axon(0), axon(1))

# %%
h.finitialize (-65 * mV)
# Out:
# 1.0

# %%
my_plot = rvp.plot(plotly, name="t=0", line={"width":4})
my_plot = my_plot.update_layout({
    "xaxis_title": "position (um)",
    "yaxis_title": "membrane potential (mV)"
})

# %%
my_plot.show()

# %%
import numpy as np
#for tstop in  [0.5]:
 #   h.continuerun(tstop)
  #  my_plot = rvp.plot(my_plot, name=f"t={tstop}", line={"width":4})

#for tstop in np.arange(0.5, 10.5, 0.5):
 #   h.continuerun(tstop)
  #  my_plot = rvp.plot(my_plot, name=f"t={tstop}", line={"width":4})

for tstop in [0.5, 1, 1.5]:
    h.continuerun(tstop)
    my_plot = rvp.plot(my_plot, name=f"t={tstop}", line={"width":4})

# %%
my_plot = my_plot.update_layout({
    "xaxis_title": "position (um)",
    "yaxis_title": "membrane potential (mV)"
})

# %%
my_plot.show()
